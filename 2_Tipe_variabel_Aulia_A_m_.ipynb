# %% [markdown]
# <a href="https://colab.research.google.com/github/auliaghnim/KKA-X-Semester-1-AuliaAM/blob/main/2_Tipe_variabel_Aulia_A_m_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print ("auliaaghni.2025@gmail.com")
print ("auliaaghni.2025@gmail.com")
print ("auliaaghni.2025@gmail.com")
# Out:
# auliaaghni.2025@gmail.com
# auliaaghni.2025@gmail.com
# auliaaghni.2025@gmail.com

# %%
email_user_1 = "auliaaghni.2025@gmail.com"

print (email_user_1)
print (email_user_1)
print (email_user_1)
# Out:
# auliaaghni.2025@gmail.com
# auliaaghni.2025@gmail.com
# auliaaghni.2025@gmail.com

# %% [markdown]
# #Peraturan penulisan Variabel

# %%
#sensitif terhadap kapital
email_user_2 = "Keenan Akbar"

print (Email_user_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2848070266.py in <cell line: 0>()
#       1 email_user_2 = "Keenan Akbar"
#       2
# ----> 3 print (Email_user_2)
#
# NameError: name 'Email_user_2' is not defined

# %%
email_user_2 = "Keenan Akbar"

print (email_user_2)
# Out:
# Keenan Akbar

# %%
emailuser2 = "Yoga Armando"

print (emailuser2)
# Out:
# Yoga Armando

# %%
#hanya boleh menggunakan huruf, angka dan underscore

email user 3 = "Dimas Esa"

print = (email user 3)
# Out:
#   File "/tmp/ipython-input-85535808.py", line 3
#     email user 3 = "Dimas Esa"
#           ^
# SyntaxError: invalid syntax

# %%
emailUser3 = "Dimas Esa"

print (emailUser3)
# Out:
# Dimas Esa

# %%
#Tidak boleh didahului oleh angka

4_email_user = "Hanafi Naufal"

print (4_email_user
# Out:
#   File "/tmp/ipython-input-1240774503.py", line 3
#     4_email_user = "Hanafi Naufal"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci python

for = "Naufal Fajri"

print (for)
# Out:
#   File "/tmp/ipython-input-1536645806.py", line 3
#     for = "Naufal Fajri"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Naufal Fajri"

print (For)
# Out:
# Naufal Fajri

# %%
print = "Alif Nadya"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2601485791.py in <cell line: 0>()
#       1 print = "Alif Nadya"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"

print (Print)
# Out:
# Alif Nadya

# %%
_ = "Azka Alifta"

# %%
print (_)
# Out:
# Azka Alifta

# %%
_ = "Kenzo Aliando"

# %%
print (_)
# Out:
# Azka Alifta

# %%
Nama = "Ahmad Fauzi"
Kelas = "X.12"
Hobi = "Membaca"

# %% [markdown]
# #Assignment

# %%
#single assignment

beratbadansiswa1 = 90
print (beratbadansiswa1)
# Out:
# 90

# %%
#Multiple assignment

nilai_kka_dias, nilai_kka_azka = 99, 98

print (nilai_kka_azka)
print (nilai_kka_dias)
# Out:
# 98
# 99

# %%
nilai_kka_dias, nilai_kka_azka = 99, 98, 70
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1565232729.py in <cell line: 0>()
# ----> 1 nilai_kka_dias, nilai_kka_azka = 99, 98, 70
#
# ValueError: too many values to unpack (expected 2)

# %%
usia_anwar = usia_sahda = 20

print (usia_anwar)
print (usia_sahda)
# Out:
# 20
# 20

# %%
nama = "Andi"

print (nama)
# Out:
# Andi

# %%
nama, umur, kelas = "budi", 15, "9A"

print (nama, umur, kelas)
# Out:
# budi 15 9A

# %%
berat_andi = berat_siti = berat_eko = 45.5

print(berat_andi, berat_siti, berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #operator pada phyton

# %%
#Tanpa variabel

print (2+8)
# Out:
# 10

# %%
#Operand disimpan ke variabel

kelereng_dias = 2
kelereng_azka = 8
print (kelereng_dias+kelereng_azka)
# Out:
# 10

# %%
#Hasil operasi disimpan ke variabel

total_kelereng = 8+2
print (total_kelereng)
# Out:
# 10

# %%
#operand dan hasil operasi disimpan ke variabel

kelereng_azka = 8
kelereng_dias = 2
total_kelereng = kelereng_azka+kelereng_dias
print (total_kelereng)
# Out:
# 10

# %%
print (24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print (total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print (banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus
print (total_jumlah_botol)
# Out:
# 72

# %%
x=y=z=100
print (x)
# Out:
# 100

# %% [markdown]
# #Jenis Tipe Variabel

# %%
a = "handayarni"
print (a)
type (a)
# Out:
# handayarni
# str

# %%
b = -0.001
print (b)
type (b)
# Out:
# -0.001
# float

# %%
c = -50
print (c)
type (c)
# Out:
# -50
# int

# %%
d = True
print (d)
type (d)
# Out:
# True
# bool

# %%
d = true
print (d)
type (d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-607360114.py in <cell line: 0>()
# ----> 1 d = true
#       2 print (d)
#       3 type (d)
#
# NameError: name 'true' is not defined

# %%
e = 1,89
print (e)
type (e)
# Out:
# (1, 89)
# tuple

# %%
x = "False"
print (x)
type (x)
# Out:
# False
# str

# %%
type (-500)
# Out:
# int

# %%
k = float(88)
print (k)
type (k)
# Out:
# 88.0
# float

# %%
z = float(-100)
print (z)
type (z)
# Out:
# -100.0
# float

# %% [markdown]
# #perubahan tipe variabel

# %%
f = 8.9
print (f)
type (f)
# Out:
# 8.9
# float

# %%
f = int(f)
print (f)
type (f)
# Out:
# 8
# int

# %%
g = -2.05
print (g)
type (g)
# Out:
# -2.05
# float

# %%
g = int(g)
print (g)
type (g)
# Out:
# -2
# int

# %%
g = bool(g)
print (g)
type (g)
# Out:
# True
# bool

# %%
h = True
print (h)
type (h)
# Out:
# True
# bool

# %%
h = int(h)
print (h)
type (h)
# Out:
# 1
# int

# %%
tinggi_nino = 170
berat_nino = 55
umur_nino = 23

tinggi_minimal = 165
berat_minimal = 50
umur_maksimal = 25

print((tinggi_nino >= tinggi_minimal) and (berat_nino >= berat_minimal) and (umur_nino <= umur_maksimal))
# Out:
# True

# %% [markdown]
# #operator perbandingan

# %%
print(6 >= 6)
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %% [markdown]
# #operator logika

# %%
print(not(5 <= 5))
# Out:
# False

# %%
print(8 > 7 and 6 < 5)
# Out:
# False

# %%
print(7 <= 1 or 2 != 2)
# Out:
# False

# %%
print(not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print (not( 5 < 10 or 5 <= 10 ))
# Out:
# False
