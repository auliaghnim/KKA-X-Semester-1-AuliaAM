# %% [markdown]
# <a href="https://colab.research.google.com/github/auliaghnim/KKA-X-Semester-1-AuliaAM/blob/main/3_Aplikasi_sederhana_X_1_Aulia_Aghni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Aulia Aghni Mardhatilla
#
# No : 8
#
# Kelas : X.1

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi Panjang

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm) : "))
lebar = int(input("Masukkan lebar dari persegi panjang (cm) : "))

luas = panjang * lebar
print (f"\nLuas dari persegi panjangnya adalah {luas} cm^2.")
# Out:
# Masukkan panjang dari persegi panjang (cm) : 5
# Masukkan lebar dari persegi panjang (cm) : 4
#
# Luas dari persegi panjangnya adalah 20 cm^2.

# %% [markdown]
# #Gorilla imut
#
# #aplikasi menghitung volume balok

# %%
panjang = int(input("Masukkan panjang dari balok (cm): "))
lebar = int(input("Masukkan lebar dari balok (cm): "))
tinggi = int(input("Masukkan tinggi dari balok (cm): "))

Volume = panjang * lebar * tinggi

print(f"\nVolume dari baloknya adalah {Volume} cm^3.")
# Out:
# Masukkan panjang dari balok (cm): 4
# Masukkan lebar dari balok (cm): 5
# Masukkan tinggi dari balok (cm): 8
#
# Volume dari baloknya adalah 160 cm^3.
